# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import accuracy_score, recall_score, f1_score,precision_score
from sklearn.metrics import roc_curve, roc_auc_score

# %%
df = pd.read_csv("heart.csv")

# %%
df.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
# 5              N      0.0       Up             0
# 6              N      0.0       Up             0
# 7              N      0.0       Up             0
# 8              Y      1.5     Flat             1
# 9              N      0.0       Up             0

# %%
df.tail(5)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.describe(include="object")
# Out:
#         Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# count   918           918        918            918      918
# unique    2             4          3              2        3
# top       M           ASY     Normal              N     Flat
# freq    725           496        552            547      460

# %%
df.nunique()
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# dtype: int64

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['c_HeartDisease']=df['HeartDisease'].map({1:'heart disease',0:'Normal'})

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease c_HeartDisease
# 0      172              N      0.0       Up             0         Normal
# 1      156              N      1.0     Flat             1  heart disease
# 2       98              N      0.0       Up             0         Normal
# 3      108              Y      1.5     Flat             1  heart disease
# 4      122              N      0.0       Up             0         Normal
# ..     ...            ...      ...      ...           ...            ...
# 913    132              N      1.2     Flat             1  heart disease
# 914    141              N      3.4     Flat             1  heart disease
# 915    115              Y      1.2     Flat             1  heart disease
# 916    174              N      0.0     Flat             1  heart disease
# 917    173              N      0.0       Up             0         Normal
#
# [918 rows x 13 columns]

# %%
fig = plt.figure(figsize=(12, 6))
gs = fig.add_gridspec(1, 2, width_ratios=[2, 1])

ax1 = fig.add_subplot(gs[0])
sns.countplot(x='c_HeartDisease', data=df, palette=[ 'green','red'],ax=ax1)
ax1.set_title('Count of HeartDisease ')
ax1.set_xlabel('Heart Disease')

ax2 = fig.add_subplot(gs[1])
types = df['c_HeartDisease'].value_counts()
ax2.pie(types, labels=types.index, autopct='%1.1f%%',colors=['red', 'green'])
ax2.set_title('rate of HeartDisease')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
gs = fig.add_gridspec(1, 2, width_ratios=[2, 1])

ax1 = fig.add_subplot(gs[0])
sns.countplot( x='Sex',hue='c_HeartDisease', data=df, palette=[ 'green','red'],ax=ax1)
ax1.set_title('Count of HeartDisease by Sex')
ax1.set_xlabel('Sex')

ax2 = fig.add_subplot(gs[1])
types = df['Sex'].value_counts()
ax2.pie(types, labels=types.index, autopct='%1.1f%%')
ax2.set_title('rate of Sex')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
gs = fig.add_gridspec(1, 2, width_ratios=[2, 1])

ax1 = fig.add_subplot(gs[0])
sns.countplot( x='ChestPainType',hue='c_HeartDisease', data=df, palette=[ 'green','red'],ax=ax1)
ax1.set_title('Count of HeartDisease by ChestPainType')


ax2 = fig.add_subplot(gs[1])
types = df['ChestPainType'].value_counts()
ax2.pie(types, labels=types.index, autopct='%1.1f%%')
ax2.set_title('rate of ChestPainType')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
gs = fig.add_gridspec(1, 2, width_ratios=[2, 1])

ax1 = fig.add_subplot(gs[0])
sns.countplot( x='RestingECG',hue='c_HeartDisease', data=df, palette=[ 'green','red'],ax=ax1)
ax1.set_title('Count of HeartDisease by RestingECG')


ax2 = fig.add_subplot(gs[1])
types = df['RestingECG'].value_counts()
ax2.pie(types, labels=types.index, autopct='%1.1f%%')
ax2.set_title('rate of RestingECG')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
gs = fig.add_gridspec(1, 2, width_ratios=[2, 1])

ax1 = fig.add_subplot(gs[0])
sns.countplot( x='ExerciseAngina',hue='c_HeartDisease', data=df, palette=[ 'green','red'],ax=ax1)
ax1.set_title('Count of HeartDisease by ExerciseAngina')


ax2 = fig.add_subplot(gs[1])
types = df['ExerciseAngina'].value_counts()
ax2.pie(types, labels=types.index, autopct='%1.1f%%')
ax2.set_title('rate of ExerciseAngina')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
gs = fig.add_gridspec(1, 2, width_ratios=[2, 1])

ax1 = fig.add_subplot(gs[0])
sns.countplot( x='ST_Slope',hue='c_HeartDisease', data=df, palette=[ 'green','red'],ax=ax1)
ax1.set_title('Count of HeartDisease by ST_Slope')


ax2 = fig.add_subplot(gs[1])
types = df['ST_Slope'].value_counts()
ax2.pie(types, labels=types.index, autopct='%1.1f%%')
ax2.set_title('rate of ST_Slope')

plt.tight_layout()
plt.show()

# %%
num_cols=df.select_dtypes(include=['number']).columns
fig, axes = plt.subplots(len(num_cols), 1, figsize=(8, 6 * len(num_cols)))
axes = axes.flatten()
for i, column in enumerate(df[num_cols]):
    sns.histplot(x=df[column], hue=df['c_HeartDisease'], ax=axes[i])
    axes[i].set_title(f'Histogram for {column}')
    axes[i].set_xlabel(column)

plt.tight_layout(h_pad=2, w_pad=2)
plt.show()

# %%
num_cols=df.select_dtypes(include=['number']).columns
fig, axes = plt.subplots(len(num_cols), 1, figsize=(8, 6 * len(num_cols)))
axes = axes.flatten()
for i, column in enumerate(df[num_cols]):
    sns.boxplot(x=df[column], ax=axes[i])
    axes[i].set_title(f'box for {column}')
    axes[i].set_xlabel(column)

plt.tight_layout(h_pad=2, w_pad=2)
plt.show()

# %%
def handle_outliers(column):
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  low_bound = Q1 - 1.5*IQR
  high_bound = Q3 + 1.5*IQR
  df[column] = df[column].clip(lower = low_bound, upper = high_bound)

for column in num_cols:
  handle_outliers(column)

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140        289.0          0     Normal
# 1     49   F           NAP        160        180.0          0     Normal
# 2     37   M           ATA        130        283.0          0         ST
# 3     48   F           ASY        138        214.0          0     Normal
# 4     54   M           NAP        150        195.0          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110        264.0          0     Normal
# 914   68   M           ASY        144        193.0          0     Normal
# 915   57   M           ASY        130        131.0          0     Normal
# 916   57   F           ATA        130        236.0          0        LVH
# 917   38   M           NAP        138        175.0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease c_HeartDisease
# 0      172              N      0.0       Up             0         Normal
# 1      156              N      1.0     Flat             1  heart disease
# 2       98              N      0.0       Up             0         Normal
# 3      108              Y      1.5     Flat             1  heart disease
# 4      122              N      0.0       Up             0         Normal
# ..     ...            ...      ...      ...           ...            ...
# 913    132              N      1.2     Flat             1  heart disease
# 914    141              N      3.4     Flat             1  heart disease
# 915    115              Y      1.2     Flat             1  heart disease
# 916    174              N      0.0     Flat             1  heart disease
# 917    173              N      0.0       Up             0         Normal
#
# [918 rows x 13 columns]

# %%
df.drop('c_HeartDisease',axis=1,inplace=True)

# %%
cat_cols=df.select_dtypes(include=['object']).columns
cat_cols
# Out:
# Index(['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'], dtype='object')

# %%
label_encoder = LabelEncoder()
for col in cat_cols:
    df[col] = label_encoder.fit_transform(df[col])

# %%
df.corr().style.background_gradient(cmap='coolwarm').format("{:.1%}")
# Out:
# <style type="text/css">
# #T_5892c_row0_col0, #T_5892c_row1_col1, #T_5892c_row2_col2, #T_5892c_row3_col3, #T_5892c_row4_col4, #T_5892c_row6_col6, #T_5892c_row7_col7, #T_5892c_row8_col8, #T_5892c_row9_col9, #T_5892c_row10_col10, #T_5892c_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5892c_row0_col1, #T_5892c_row2_col9 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_5892c_row0_col2, #T_5892c_row1_col6, #T_5892c_row7_col9 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_5892c_row0_col3 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_5892c_row0_col4, #T_5892c_row2_col11 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_5892c_row0_col5, #T_5892c_row1_col5, #T_5892c_row2_col5, #T_5892c_row3_col5, #T_5892c_row4_col5, #T_5892c_row5_col0, #T_5892c_row5_col1, #T_5892c_row5_col2, #T_5892c_row5_col3, #T_5892c_row5_col4, #T_5892c_row5_col5, #T_5892c_row5_col6, #T_5892c_row5_col7, #T_5892c_row5_col8, #T_5892c_row5_col9, #T_5892c_row5_col10, #T_5892c_row5_col11, #T_5892c_row6_col5, #T_5892c_row7_col5, #T_5892c_row8_col5, #T_5892c_row9_col5, #T_5892c_row10_col5, #T_5892c_row11_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_5892c_row0_col6, #T_5892c_row6_col7, #T_5892c_row10_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_5892c_row0_col7, #T_5892c_row7_col1, #T_5892c_row7_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_5892c_row0_col8, #T_5892c_row3_col9, #T_5892c_row4_col7 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_5892c_row0_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_5892c_row0_col10, #T_5892c_row3_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_5892c_row0_col11 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_5892c_row1_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_5892c_row1_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_5892c_row1_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_5892c_row1_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_5892c_row1_col7, #T_5892c_row9_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_5892c_row1_col8, #T_5892c_row3_col11, #T_5892c_row8_col0, #T_5892c_row10_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_5892c_row1_col9, #T_5892c_row3_col8 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_5892c_row1_col10, #T_5892c_row9_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_5892c_row1_col11 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_5892c_row2_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_5892c_row2_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_5892c_row2_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_5892c_row2_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_5892c_row2_col6 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_5892c_row2_col7, #T_5892c_row2_col10 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_5892c_row2_col8 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_5892c_row3_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_5892c_row3_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_5892c_row3_col2, #T_5892c_row3_col4, #T_5892c_row6_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_5892c_row3_col7, #T_5892c_row11_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_5892c_row3_col10 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_5892c_row4_col0, #T_5892c_row4_col11, #T_5892c_row11_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_5892c_row4_col1, #T_5892c_row4_col6, #T_5892c_row7_col0, #T_5892c_row7_col3, #T_5892c_row10_col8, #T_5892c_row10_col9, #T_5892c_row10_col11, #T_5892c_row11_col2, #T_5892c_row11_col4, #T_5892c_row11_col7, #T_5892c_row11_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5892c_row4_col2, #T_5892c_row6_col9 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_5892c_row4_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_5892c_row4_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_5892c_row4_col9 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_5892c_row4_col10 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_5892c_row6_col1, #T_5892c_row6_col2, #T_5892c_row8_col6, #T_5892c_row9_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_5892c_row6_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_5892c_row6_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_5892c_row6_col8, #T_5892c_row6_col10 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_5892c_row6_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_5892c_row7_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_5892c_row7_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_5892c_row7_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_5892c_row7_col10 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_5892c_row7_col11 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_5892c_row8_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_5892c_row8_col2, #T_5892c_row8_col7 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_5892c_row8_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_5892c_row8_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_5892c_row8_col9 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_5892c_row8_col10, #T_5892c_row10_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_5892c_row8_col11 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_5892c_row9_col0 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_5892c_row9_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_5892c_row9_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_5892c_row9_col7 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_5892c_row9_col8 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_5892c_row9_col10 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_5892c_row9_col11 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_5892c_row10_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_5892c_row10_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_5892c_row10_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_5892c_row10_col7 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_5892c_row11_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_5892c_row11_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_5892c_row11_col8 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_5892c_row11_col9 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# </style>
# <table id="T_5892c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5892c_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_5892c_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_5892c_level0_col2" class="col_heading level0 col2" >ChestPainType</th>
#       <th id="T_5892c_level0_col3" class="col_heading level0 col3" >RestingBP</th>
#       <th id="T_5892c_level0_col4" class="col_heading level0 col4" >Cholesterol</th>
#       <th id="T_5892c_level0_col5" class="col_heading level0 col5" >FastingBS</th>
#       <th id="T_5892c_level0_col6" class="col_heading level0 col6" >RestingECG</th>
#       <th id="T_5892c_level0_col7" class="col_heading level0 col7" >MaxHR</th>
#       <th id="T_5892c_level0_col8" class="col_heading level0 col8" >ExerciseAngina</th>
#       <th id="T_5892c_level0_col9" class="col_heading level0 col9" >Oldpeak</th>
#       <th id="T_5892c_level0_col10" class="col_heading level0 col10" >ST_Slope</th>
#       <th id="T_5892c_level0_col11" class="col_heading level0 col11" >HeartDisease</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5892c_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_5892c_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_5892c_row0_col1" class="data row0 col1" >5.6%</td>
#       <td id="T_5892c_row0_col2" class="data row0 col2" >-7.7%</td>
#       <td id="T_5892

# %%
df.drop('RestingECG',axis=1,inplace=True)
df.drop('FastingBS',axis=1,inplace=True)

# %%
df.corr().style.background_gradient(cmap='coolwarm').format("{:.1%}")
# Out:
# <style type="text/css">
# #T_786f9_row0_col0, #T_786f9_row1_col1, #T_786f9_row2_col2, #T_786f9_row3_col3, #T_786f9_row4_col4, #T_786f9_row5_col5, #T_786f9_row6_col6, #T_786f9_row7_col7, #T_786f9_row8_col8, #T_786f9_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_786f9_row0_col1, #T_786f9_row2_col7 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_786f9_row0_col2, #T_786f9_row5_col7 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_786f9_row0_col3 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_786f9_row0_col4, #T_786f9_row2_col9 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_786f9_row0_col5, #T_786f9_row5_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_786f9_row0_col6, #T_786f9_row3_col7, #T_786f9_row4_col5 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_786f9_row0_col7 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_786f9_row0_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_786f9_row0_col9 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_786f9_row1_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_786f9_row1_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_786f9_row1_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_786f9_row1_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_786f9_row1_col5, #T_786f9_row7_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_786f9_row1_col6, #T_786f9_row3_col9, #T_786f9_row6_col0, #T_786f9_row8_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_786f9_row1_col7, #T_786f9_row3_col6 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_786f9_row1_col8, #T_786f9_row7_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_786f9_row1_col9 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_786f9_row2_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_786f9_row2_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_786f9_row2_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_786f9_row2_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_786f9_row2_col5, #T_786f9_row2_col8 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_786f9_row2_col6 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_786f9_row3_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_786f9_row3_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_786f9_row3_col2, #T_786f9_row3_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_786f9_row3_col5, #T_786f9_row9_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_786f9_row3_col8 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_786f9_row4_col0, #T_786f9_row4_col9 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_786f9_row4_col1, #T_786f9_row5_col0, #T_786f9_row5_col3, #T_786f9_row8_col6, #T_786f9_row8_col7, #T_786f9_row8_col9, #T_786f9_row9_col2, #T_786f9_row9_col4, #T_786f9_row9_col5, #T_786f9_row9_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_786f9_row4_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_786f9_row4_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_786f9_row4_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_786f9_row4_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_786f9_row4_col8 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_786f9_row5_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_786f9_row5_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_786f9_row5_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_786f9_row5_col8 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_786f9_row5_col9 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_786f9_row6_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_786f9_row6_col2, #T_786f9_row6_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_786f9_row6_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_786f9_row6_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_786f9_row6_col7 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_786f9_row6_col8, #T_786f9_row8_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_786f9_row6_col9 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_786f9_row7_col0 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_786f9_row7_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_786f9_row7_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_786f9_row7_col5 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_786f9_row7_col6 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_786f9_row7_col8 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_786f9_row7_col9 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_786f9_row8_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_786f9_row8_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_786f9_row8_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_786f9_row8_col5 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_786f9_row9_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_786f9_row9_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_786f9_row9_col6 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_786f9_row9_col7 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# </style>
# <table id="T_786f9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_786f9_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_786f9_level0_col1" class="col_heading level0 col1" >Sex</th>
#       <th id="T_786f9_level0_col2" class="col_heading level0 col2" >ChestPainType</th>
#       <th id="T_786f9_level0_col3" class="col_heading level0 col3" >RestingBP</th>
#       <th id="T_786f9_level0_col4" class="col_heading level0 col4" >Cholesterol</th>
#       <th id="T_786f9_level0_col5" class="col_heading level0 col5" >MaxHR</th>
#       <th id="T_786f9_level0_col6" class="col_heading level0 col6" >ExerciseAngina</th>
#       <th id="T_786f9_level0_col7" class="col_heading level0 col7" >Oldpeak</th>
#       <th id="T_786f9_level0_col8" class="col_heading level0 col8" >ST_Slope</th>
#       <th id="T_786f9_level0_col9" class="col_heading level0 col9" >HeartDisease</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_786f9_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_786f9_row0_col0" class="data row0 col0" >100.0%</td>
#       <td id="T_786f9_row0_col1" class="data row0 col1" >5.6%</td>
#       <td id="T_786f9_row0_col2" class="data row0 col2" >-7.7%</td>
#       <td id="T_786f9_row0_col3" class="data row0 col3" >27.0%</td>
#       <td id="T_786f9_row0_col4" class="data row0 col4" >-8.8%</td>
#       <td id="T_786f9_row0_col5" class="data row0 col5" >-38.2%</td>
#       <td id="T_786f9_row0_col6" class="data row0 col6" >21.6%</td>
#       <td id="T_786f9_row0_col7" class="data row0 col7" >26.3%</td>
#       <td id="T_786f9_row0_col8" class="data row0 col8" >-26.8%</td>
#       <td id="T_786f9_row0_col9" class="data row0 col9" >28.2%</td>
#     </tr>
#     <tr>
#       <th id="T_786f9_level0_row1" class="row_heading level0 row1" >Sex</th>
#       <td id="T_786f9_row1_col0" class="data row1 col0" >5.6%</td>
#       <td id="T_786f9_row1_col1" class="data row1 col1" >100.0%</td>
#       <td id="T_786f9_row1_col2" class="data row1 col2" >-12.7%</td>
#       <td id="T_786f9_row1_col3" class="data row1 col3" >1.7%</td>
#       <td id="T_786f9_row1_col4" class="data row1 col4" >-20.4%</td>
#       <td id="T_786f9_row1_col5" class="data row1 col5" >-18.9%</td>
#       <td id="T_786f9_row1_col6" class="data row1 col6" >19.1%</td>
#       <td id="T_786f9_row1_col7" class="data row1 col7" >11.2%</td>
#       <td id="T_786f9_row1_col8" class="data row1 col8" >-15.1%</td>
#       <td id="T_786f9_row1_col9" class="data row1 col9" >30.5%</td>
#     </tr>
#     <tr>
#       <th id="T_786f9_level0_row2" class="row_heading level0 row2" >ChestPainType</th>
#       <td id="T_786f9_row2_col0" class="data row2 col0" >-7.7%</td>
#       <td id="T_786f9_row2_col1" class="data row2 col1" >-12.7%</td>
#       <td id="T_786

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
scaler = MinMaxScaler()
df= pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
df
# Out:
#           Age  Sex  ChestPainType  RestingBP  Cholesterol     MaxHR  \
# 0    0.244898  1.0       0.333333      0.625     0.683667  0.779412
# 1    0.428571  0.0       0.666667      0.875     0.393000  0.661765
# 2    0.183673  1.0       0.333333      0.500     0.667667  0.235294
# 3    0.408163  0.0       0.000000      0.600     0.483667  0.308824
# 4    0.530612  1.0       0.666667      0.750     0.433000  0.411765
# ..        ...  ...            ...        ...          ...       ...
# 912  0.346939  1.0       1.000000      0.250     0.617000  0.485294
# 913  0.816327  1.0       0.000000      0.675     0.427667  0.551471
# 914  0.591837  1.0       0.000000      0.500     0.262333  0.360294
# 915  0.591837  0.0       0.333333      0.500     0.542333  0.794118
# 916  0.204082  1.0       0.666667      0.600     0.379667  0.786765
#
#      ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# 0               0.0  0.375000       1.0           0.0
# 1               0.0  0.541667       0.5           1.0
# 2               0.0  0.375000       1.0           0.0
# 3               1.0  0.625000       0.5           1.0
# 4               0.0  0.375000       1.0           0.0
# ..              ...       ...       ...           ...
# 912             0.0  0.575000       0.5           1.0
# 913             0.0  0.941667       0.5           1.0
# 914             1.0  0.575000       0.5           1.0
# 915             0.0  0.375000       0.5           1.0
# 916             0.0  0.375000       1.0           0.0
#
# [917 rows x 10 columns]

# %%
x=df.drop('HeartDisease',axis=1)
y=df['HeartDisease']

# %%
x
# Out:
#           Age  Sex  ChestPainType  RestingBP  Cholesterol     MaxHR  \
# 0    0.244898  1.0       0.333333      0.625     0.683667  0.779412
# 1    0.428571  0.0       0.666667      0.875     0.393000  0.661765
# 2    0.183673  1.0       0.333333      0.500     0.667667  0.235294
# 3    0.408163  0.0       0.000000      0.600     0.483667  0.308824
# 4    0.530612  1.0       0.666667      0.750     0.433000  0.411765
# ..        ...  ...            ...        ...          ...       ...
# 912  0.346939  1.0       1.000000      0.250     0.617000  0.485294
# 913  0.816327  1.0       0.000000      0.675     0.427667  0.551471
# 914  0.591837  1.0       0.000000      0.500     0.262333  0.360294
# 915  0.591837  0.0       0.333333      0.500     0.542333  0.794118
# 916  0.204082  1.0       0.666667      0.600     0.379667  0.786765
#
#      ExerciseAngina   Oldpeak  ST_Slope
# 0               0.0  0.375000       1.0
# 1               0.0  0.541667       0.5
# 2               0.0  0.375000       1.0
# 3               1.0  0.625000       0.5
# 4               0.0  0.375000       1.0
# ..              ...       ...       ...
# 912             0.0  0.575000       0.5
# 913             0.0  0.941667       0.5
# 914             1.0  0.575000       0.5
# 915             0.0  0.375000       0.5
# 916             0.0  0.375000       1.0
#
# [917 rows x 9 columns]

# %%
y
# Out:
# 0      0.0
# 1      1.0
# 2      0.0
# 3      1.0
# 4      0.0
#       ...
# 912    1.0
# 913    1.0
# 914    1.0
# 915    1.0
# 916    0.0
# Name: HeartDisease, Length: 917, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (733, 9)
# (184, 9)
# (733,)
# (184,)

# %%
lr=LogisticRegression()

lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
ypred1_test=lr.predict(x_test)
accuracy1_test = accuracy_score(y_test, ypred1_test)
print(f"Accuracy test: {round(accuracy1_test * 100,2)}%")

ypred1_train=lr.predict(x_train)
accuracy1_train = accuracy_score(y_train, ypred1_train)
print(f"Accuracy train: {round(accuracy1_train * 100,2)}%")
# Out:
# Accuracy test: 84.24%
# Accuracy train: 85.13%

# %%
print("Classification Report:")
print(classification_report(y_test, ypred1_test))
pecision1=precision_score(y_test,ypred1_test)
Recall1=recall_score(y_test,ypred1_test)
Fscore1=f1_score(y_test,ypred1_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.88      0.82        74
#          1.0       0.91      0.82      0.86       110
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.85      0.84       184
# weighted avg       0.85      0.84      0.84       184

# %%
conf_matrix = confusion_matrix(y_test, ypred1_test)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix ')
plt.show()

# %%
ypred1_tp=lr.predict_proba(x_test)[:, 1]
roc_auc1 = roc_auc_score(y_test,ypred1_tp)
fpr, tpr, thresholds = roc_curve(y_test, ypred1_tp)
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'AUC test = {roc_auc1:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate (Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
ypred2_test=knn.predict(x_test)
accuracy2_test = accuracy_score(y_test, ypred2_test)
print(f"Accuracy test: {round(accuracy2_test * 100,2)}%")

ypred2_train=knn.predict(x_train)
accuracy2_train = accuracy_score(y_train, ypred2_train)
print(f"Accuracy train: {round(accuracy2_train * 100,2)}%")
# Out:
# Accuracy test: 83.7%
# Accuracy train: 91.0%

# %%
print("Classification Report:")
print(classification_report(y_test, ypred2_test))
pecision2=precision_score(y_test,ypred2_test)
Recall2=recall_score(y_test,ypred2_test)
Fscore2=f1_score(y_test,ypred2_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.91      0.82        74
#          1.0       0.93      0.79      0.85       110
#
#     accuracy                           0.84       184
#    macro avg       0.83      0.85      0.84       184
# weighted avg       0.85      0.84      0.84       184

# %%
conf_matrix = confusion_matrix(y_test, ypred2_test)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix ')
plt.show()

# %%
ypred2_tp=knn.predict_proba(x_test)[:, 1]
roc_auc2 = roc_auc_score(y_test,ypred2_tp)
fpr, tpr, thresholds = roc_curve(y_test, ypred2_tp)
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'AUC test = {roc_auc2:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate (Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
ypred3_test = dt.predict(x_test)

accuracy3_test = accuracy_score(y_test, ypred3_test)
print(f"Test Accuracy: {round(accuracy3_test * 100,2)}%")

ypred3_train = dt.predict(x_train)

accuracy3_train = accuracy_score(y_train, ypred3_train)
print(f"Train Accuracy: {round(accuracy3_train * 100,2)}%")
# Out:
# Test Accuracy: 79.35%
# Train Accuracy: 100.0%

# %%
print("Classification Report:")
print(classification_report(y_test, ypred3_test))
pecision3=precision_score(y_test,ypred3_test)
Recall3=recall_score(y_test,ypred3_test)
Fscore3=f1_score(y_test,ypred3_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.82      0.76        74
#          1.0       0.87      0.77      0.82       110
#
#     accuracy                           0.79       184
#    macro avg       0.79      0.80      0.79       184
# weighted avg       0.80      0.79      0.80       184

# %%
conf_matrix = confusion_matrix(y_test, ypred3_test)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix ')
plt.show()

# %%
ypred3_tp=dt.predict_proba(x_test)[:, 1]
roc_auc3 = roc_auc_score(y_test,ypred3_tp)
fpr, tpr, thresholds = roc_curve(y_test, ypred3_tp)
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'AUC test = {roc_auc3:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate (Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
rf = RandomForestClassifier(random_state=42)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
ypred4_test = rf.predict(x_test)

accuracy4_test = accuracy_score(y_test, ypred4_test)
print(f"Test Accuracy: {round(accuracy4_test * 100,2)}%")

ypred4_train = rf.predict(x_train)

accuracy4_train = accuracy_score(y_train, ypred4_train)
print(f"Train Accuracy: {round(accuracy4_train * 100,2)}%")
# Out:
# Test Accuracy: 86.41%
# Train Accuracy: 100.0%

# %%
print("Classification Report:")
print(classification_report(y_test, ypred4_test))
pecision4=precision_score(y_test,ypred4_test)
Recall4=recall_score(y_test,ypred4_test)
Fscore4=f1_score(y_test,ypred4_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.89      0.84        74
#          1.0       0.92      0.85      0.88       110
#
#     accuracy                           0.86       184
#    macro avg       0.86      0.87      0.86       184
# weighted avg       0.87      0.86      0.87       184

# %%
conf_matrix = confusion_matrix(y_test, ypred4_test)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix ')
plt.show()

# %%
ypred4_tp=rf.predict_proba(x_test)[:, 1]
roc_auc4 = roc_auc_score(y_test,ypred4_tp)
fpr, tpr, thresholds = roc_curve(y_test, ypred4_tp)
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'AUC test = {roc_auc4:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate (Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
xgb= XGBClassifier(random_state=42)
xgb.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
ypred5_test = xgb.predict(x_test)

accuracy5_test = accuracy_score(y_test, ypred5_test)
print(f"Test Accuracy: {round(accuracy5_test * 100,2)}%")

ypred5_train = rf.predict(x_train)

accuracy5_train = accuracy_score(y_train, ypred5_train)
print(f"Train Accuracy: {round(accuracy5_train * 100,2)}%")
# Out:
# Test Accuracy: 85.33%
# Train Accuracy: 100.0%

# %%
print("Classification Report:")
print(classification_report(y_test, ypred5_test))
pecision5=precision_score(y_test,ypred5_test)
Recall5=recall_score(y_test,ypred5_test)
Fscore5=f1_score(y_test,ypred5_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.88      0.83        74
#          1.0       0.91      0.84      0.87       110
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.86      0.85       184
# weighted avg       0.86      0.85      0.85       184

# %%
conf_matrix = confusion_matrix(y_test, ypred5_test)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix ')
plt.show()

# %%
ypred5_tp=xgb.predict_proba(x_test)[:, 1]
roc_auc5 = roc_auc_score(y_test,ypred5_tp)
fpr, tpr, thresholds = roc_curve(y_test, ypred5_tp)
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'AUC test = {roc_auc5:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate (Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
svc = SVC(random_state=42)
svc.fit(x_train, y_train)
# Out:
# SVC(random_state=42)

# %%
ypred6_test = svc.predict(x_test)

accuracy6_test = accuracy_score(y_test, ypred6_test)
print(f"Test Accuracy: {round(accuracy6_test * 100,2)}%")

ypred6_train = rf.predict(x_train)

accuracy6_train = accuracy_score(y_train, ypred6_train)
print(f"Train Accuracy: {round(accuracy6_train * 100,2)}%")
# Out:
# Test Accuracy: 88.59%
# Train Accuracy: 100.0%

# %%
print("Classification Report:")
print(classification_report(y_test, ypred6_test))
pecision6=precision_score(y_test,ypred6_test)
Recall6=recall_score(y_test,ypred6_test)
Fscore6=f1_score(y_test,ypred6_test)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.86      0.86        74
#          1.0       0.91      0.90      0.90       110
#
#     accuracy                           0.89       184
#    macro avg       0.88      0.88      0.88       184
# weighted avg       0.89      0.89      0.89       184

# %%
conf_matrix = confusion_matrix(y_test, ypred6_test)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix ')
plt.show()

# %%
ypred6_tp=xgb.predict_proba(x_test)[:, 1]
roc_auc6 = roc_auc_score(y_test,ypred6_tp)
fpr, tpr, thresholds = roc_curve(y_test, ypred6_tp)
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'AUC test = {roc_auc6:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate (Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
models=pd.DataFrame({
   'Model':
    [ 'Logistic Regression','K Nearest Neighbors','Decision Tree','Random Forest','XG-Boost','SVM'],
   'Accuracy test':
    [accuracy1_test,accuracy2_test,accuracy3_test,accuracy4_test,accuracy5_test,accuracy6_test],
   'Accuracy train':
    [accuracy1_train,accuracy2_train,accuracy3_train,accuracy4_train,accuracy5_train,accuracy6_train],
   'AUC-ROC':
    [roc_auc1,roc_auc2,roc_auc3,roc_auc4,roc_auc5,roc_auc6],
   'cost possitive':
    [pecision1,pecision2,pecision3,pecision4,pecision5,pecision6],
   'cost negatives':
    [Recall1,Recall2,Recall3,Recall4,Recall5,Recall6],
   'mean cost P and cost N':
    [Fscore1,Fscore2,Fscore3,Fscore4,Fscore5,Fscore6]
})

# %%
models
# Out:
#                  Model  Accuracy test  Accuracy train   AUC-ROC  \
# 0  Logistic Regression       0.842391        0.851296  0.896560
# 1  K Nearest Neighbors       0.836957        0.909959  0.910135
# 2        Decision Tree       0.793478        1.000000  0.798526
# 3        Random Forest       0.864130        1.000000  0.938022
# 4             XG-Boost       0.853261        1.000000  0.937101
# 5                  SVM       0.885870        1.000000  0.937101
#
#    cost possitive  cost negatives  mean cost P and cost N
# 0        0.909091        0.818182                0.861244
# 1        0.925532        0.790909                0.852941
# 2        0.867347        0.772727                0.817308
# 3        0.920792        0.845455                0.881517
# 4        0.910891        0.836364                0.872038
# 5        0.908257        0.900000                0.904110

# %%
models = models.sort_values(by='Accuracy test', ascending=False)
plt.figure(figsize = (14, 8))
fig = px.bar(models, x = 'Model', y ='Accuracy test',pattern_shape = 'Accuracy test',color = 'Model')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="19afac27-589d-4c0d-928a-d9162eca923c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19afac27-589d-4c0d-928a-d9162eca923c")) {                    Plotly.newPlot(                        "19afac27-589d-4c0d-928a-d9162eca923c",                        [{"alignmentgroup":"True","hovertemplate":"Model=%{x}\u003cbr\u003eAccuracy test=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SVM, 0.8858695652173914","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"SVM, 0.8858695652173914","offsetgroup":"SVM, 0.8858695652173914","orientation":"v","showlegend":true,"textposition":"auto","x":["SVM"],"xaxis":"x","y":[0.8858695652173914],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Model=%{x}\u003cbr\u003eAccuracy test=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Random Forest, 0.8641304347826086","marker":{"color":"#EF553B","pattern":{"shape":"\u002f"}},"name":"Random Forest, 0.8641304347826086","offsetgroup":"Random Forest, 0.8641304347826086","orientation":"v","showlegend":true,"textposition":"auto","x":["Random Forest"],"xaxis":"x","y":[0.8641304347826086],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Model=%{x}\u003cbr\u003eAccuracy test=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"XG-Boost, 0.8532608695652174","marker":{"color":"#00cc96","pattern":{"shape":"\\"}},"name":"XG-Boost, 0.8532608695652174","offsetgroup":"XG-Boost, 0.8532608695652174","orientation":"v","showlegend":true,"textposition":"auto","x":["XG-Boost"],"xaxis":"x","y":[0.8532608695652174],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Model=%{x}\u003cbr\u003eAccuracy test=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Logistic Regression, 0.842391304347826","marker":{"color":"#ab63fa","pattern":{"shape":"x"}},"name":"Logistic Regression, 0.842391304347826","offsetgroup":"Logistic Regression, 0.842391304347826","orientation":"v","showlegend":true,"textposition":"auto","x":["Logistic Regression"],"xaxis":"x","y":[0.842391304347826],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Model=%{x}\u003cbr\u003eAccuracy test=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"K Nearest Neighbors, 0.8369565217391305","marker":{"color":"#FFA15A","pattern":{"shape":"+"}},"name":"K Nearest Neighbors, 0.8369565217391305","offsetgroup":"K Nearest Neighbors, 0.8369565217391305","orientation":"v","showlegend":true,"textposition":"auto","x":["K Nearest Neighbors"],"xaxis":"x","y":[0.8369565217391305],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Model=%{x}\u003cbr\u003eAccuracy test=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Decision Tree, 0.7934782608695652","marker":{"color":"#19d3f3","pattern":{"shape":"."}},"name":"Decision Tree, 0.7934782608695652","offsetgroup":"Decision Tree, 0.7934782608695652","orientation":"v","showlegend":true,"textposition":"auto","x":["Decision Tree"],"xaxis":"x","y":[0.7934782608695652],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22 ...
